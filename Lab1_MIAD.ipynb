# %% [markdown]
# <a href="https://colab.research.google.com/github/gorobecb/MIAD-labs/blob/main/Lab1_MIAD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Воробйов Андрій, ІПЗм-24-2, Варіант 7

# %%
import csv
import pandas as pd

FILENAME = 'films.csv'
KAGGLE_DATASET_PATH = 'billionaire_list_20yrs.csv'

# %% [markdown]
# ## Завдання 1
# *Створити csv-файл, використовуючи функцію writer або клас DictWriter.*

# %%
data = [
    { "name": "Преслідування","year": 1998,"category": "Драма, Трилер","genre": "Нео-нуар","duration": 69,"rating": 7.5 },
    { "name": "Бетмен: Початок","year": 2005,"category": "Бойовик, Пригоди","genre": "Супергеройський","duration": 140,"rating": 8.2 },
    { "name": "Престиж","year": 2006,"category": "Драма, Трилер","genre": "Містика","duration": 130,"rating": 8.5 },
    { "name": "Темний Лицар","year": 2008,"category": "Бойовик, Кримінал","genre": "Супергеройський","duration": 152,"rating": 9.0 },
    { "name": "Початок","year": 2010,"category": "Наукова фантастика, Трилер","genre": "Психологічний","duration": 148,"rating": 8.8 },
    { "name": "Темний Лицар: Відродження","year": 2012,"category": "Бойовик, Драма","genre": "Супергеройський","duration": 164,"rating": 8.4 },
    { "name": "Інтерстеллар","year": 2014,"category": "Наукова фантастика, Драма","genre": "Космічна опера","duration": 169,"rating": 8.6 },
    { "name": "Дюнкерк","year": 2017,"category": "Військовий, Драма","genre": "Історичний","duration": 106,"rating": 7.9 },
    { "name": "Тенет","year": 2020,"category": "Наукова фантастика, Екшн","genre": "Шпигунський","duration": 150,"rating": 7.3 },
    { "name": "Оппенгеймер","year": 2023,"category": "Біографія, Драма","genre": "Історичний","duration": 180,"rating": 8.4 }
]

with open(FILENAME, 'w', newline='') as file:
  writer = csv.DictWriter(file, data[0].keys())
  writer.writeheader()
  writer.writerows(data)

# %% [markdown]
# ## Завдання 2
# *Провести первинний аналіз створеного файлу*

# %%
df = pd.read_csv(FILENAME)
df.head()
# Out:
#               name  year                    category            genre  \
# 0    Преслідування  1998               Драма, Трилер         Нео-нуар
# 1  Бетмен: Початок  2005            Бойовик, Пригоди  Супергеройський
# 2          Престиж  2006               Драма, Трилер          Містика
# 3     Темний Лицар  2008           Бойовик, Кримінал  Супергеройський
# 4          Початок  2010  Наукова фантастика, Трилер    Психологічний
#
#    duration  rating
# 0        69     7.5
# 1       140     8.2
# 2       130     8.5
# 3       152     9.0
# 4       148     8.8

# %%
df.tail()
# Out:
#                         name  year                   category  \
# 5  Темний Лицар: Відродження  2012             Бойовик, Драма
# 6               Інтерстеллар  2014  Наукова фантастика, Драма
# 7                    Дюнкерк  2017          Військовий, Драма
# 8                      Тенет  2020   Наукова фантастика, Екшн
# 9                Оппенгеймер  2023           Біографія, Драма
#
#              genre  duration  rating
# 5  Супергеройський       164     8.4
# 6   Космічна опера       169     8.6
# 7       Історичний       106     7.9
# 8      Шпигунський       150     7.3
# 9       Історичний       180     8.4

# %% [markdown]
# ### Статистичні характеристики

# %%
df.describe()
# Out:
#               year    duration     rating
# count    10.000000   10.000000  10.000000
# mean   2011.300000  140.800000   8.260000
# std       7.528465   32.686389   0.546097
# min    1998.000000   69.000000   7.300000
# 25%    2006.500000  132.500000   7.975000
# 50%    2011.000000  149.000000   8.400000
# 75%    2016.250000  161.000000   8.575000
# max    2023.000000  180.000000   9.000000

# %% [markdown]
# ## Завдання 3
# *Завантажити файл Kaggle, провести первинне дослідження набору даних*

# %% [markdown]
# Файл попередньо завантажений як [billionaire_list_20yrs.csv](https://www.kaggle.com/datasets/salimwid/global-billionaire-wealth-and-sources-2002-2023/data)

# %%
df = pd.read_csv("billionaire_list_20yrs.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 352369 entries, 0 to 352368
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             352369 non-null  int64
#  1   name                   352369 non-null  object
#  2   last_name              341519 non-null  object
#  3   age                    352369 non-null  int64
#  4   gender                 340477 non-null  object
#  5   time                   352369 non-null  int64
#  6   permanent_country      304678 non-null  object
#  7   company                326869 non-null  object
#  8   main_industry          352369 non-null  object
#  9   wealth_source_details  341447 non-null  object
#  10  industry               352320 non-null  object
#  11  state                  159190 non-null  object
#  12  headquarters           133655 non-null  object
#  13  countries              352369 non-null  object
# ...

# %%
df.head()
# Out:
#    Unnamed: 0                          name   last_name  age gender  time  \
# 0         675  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M  2013
# 1         676  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M  2013
# 2         677  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M  2013
# 3         678  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M  2013
# 4         679  Abdulla bin Ahmad Al Ghurair  Al Ghurair   67      M  2013
#
#             permanent_country       company main_industry  \
# 0  United Arab Emirates-Dubai  Mashreq Bank   Diversified
# 1  United Arab Emirates-Dubai  Mashreq Bank   Diversified
# 2  United Arab Emirates-Dubai  Mashreq Bank   Diversified
# 3  United Arab Emirates-Dubai  Mashreq Bank   Diversified
# 4  United Arab Emirates-Dubai  Mashreq Bank   Diversified
#
#   wealth_source_details             industry state headquarters countries  \
# 0           diversified  Diversified;Banking   NaN          NaN       are
# ...

# %%
df.tail()
# Out:
#         Unnamed: 0                name   last_name  age gender  time  \
# 352364      358313  Zygmunt Solorz-Zak  Solorz-Zak   65      M  2022
# 352365      358314  Zygmunt Solorz-Zak  Solorz-Zak   65      M  2022
# 352366      358315  Zygmunt Solorz-Zak  Solorz-Zak   65      M  2022
# 352367      358316  Zygmunt Solorz-Zak  Solorz-Zak   65      M  2022
# 352368      358317  Zygmunt Solorz-Zak  Solorz-Zak   65      M  2022
#
#        permanent_country         company          main_industry  \
# 352364     Poland-Warsaw  Cyfrowy Polsat  Media & Entertainment
# 352365     Poland-Warsaw  Cyfrowy Polsat  Media & Entertainment
# 352366     Poland-Warsaw  Cyfrowy Polsat  Media & Entertainment
# 352367     Poland-Warsaw  Cyfrowy Polsat  Media & Entertainment
# 352368     Poland-Warsaw  Cyfrowy Polsat  Media & Entertainment
#
#               wealth_source_details  \
# 352364  TV broadcasting; TV station
# 352365  TV broadcasting; TV station
# 352366  TV broadcasting; TV station
# ...

# %% [markdown]
# *Оскільки перша колонка, вочевидь, є просто порядковим номером, видаляю її*

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.describe()
# Out:
#                  age           time  annual_income  daily_income  \
# count  352369.000000  352369.000000   3.523690e+05  3.523690e+05
# mean       72.130326    2014.227824   1.437315e+08  3.937844e+05
# std        13.237945       5.474610   2.336920e+08  6.402521e+05
# min        19.000000    2002.000000   1.681350e+07  4.606400e+04
# 25%        63.000000    2010.000000   4.870500e+07  1.334380e+05
# 50%        72.000000    2015.000000   7.642500e+07  2.093830e+05
# 75%        81.000000    2019.000000   1.396560e+08  3.826190e+05
# max       117.000000    2022.000000   5.650200e+09  1.548000e+07
#
#           birth_year
# count  352369.000000
# mean     1949.869674
# std        13.237945
# min      1905.000000
# 25%      1941.000000
# 50%      1950.000000
# 75%      1959.000000
# max      2003.000000

# %% [markdown]
# *Спробую обрати людину та дізнатись як зростали статки протягом часу*

# %%
billioner_names = df['name_cleaned'].unique()
print(sorted(billioner_names))
# Out:
# ['a_jayson_adair', 'a_jerrold_perenchio', 'abdul_aziz_al_ghurair', 'abdul_majeed_alhokair', 'abdul_rasyid', 'abdulla_bin_ahmad_al_ghurair', 'abdullah_bin_sulaiman_al_rajhi', 'abdulsamad_rabiu', 'abhay_firodia', 'abhay_soi', 'abhay_vakil', 'abigail_johnson', 'abilio_dos_santos_diniz', 'achal_bakeri', 'acharya_balakrishna', 'acharya_balkrishna', 'achmad_hamami', 'adam_bowen', 'adam_foroughi', 'adam_kwok', 'adam_kwok_kai_fai', 'adam_neumann', 'adi_godrej', 'adrian_paval', 'aerin_lauder', 'agnete_kirk_thinggaard', 'ahmet_calik', 'ahmet_nazif_zorlu', 'ahsen_ozokur', 'ai_lihua', 'ai_luming', 'aidan_barclay', 'airat_shaimiev', 'aiyawatt_srivaddhanaprabha', 'ajay_banga', 'ajay_jaisinghani', 'ajay_kalsi', 'ajay_parekh', 'ajay_piramal', 'akio_nitori', 'akira_mori', 'alain_bouchard', 'alain_merieux', 'alain_taravella', 'alain_wertheimer', 'alan_auerbach', 'alan_casden', 'alan_g_hassenfeld', 'alan_gerry', 'alan_howard', 'alan_miller_1', 'alan_parker', 'alan_rydge', 'alan_trefler', 'alan_zekelman
# ...

# %%
billioner = 'wang_yong'
billioner_info = df[df['name_cleaned'] == billioner]
billioner_info.plot.bar('time', 'annual_income')
# Out:
# <Axes: xlabel='time'>
